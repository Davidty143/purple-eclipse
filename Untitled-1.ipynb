# %%
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
def load_data_from_directory(base_dir, image_size=(128, 128)):
    images = []
    labels = []
    class_names = sorted(os.listdir(base_dir))
    
    for class_idx, class_label in enumerate(class_names):
        class_path = os.path.join(base_dir, class_label)
        if not os.path.isdir(class_path):
            continue
            
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, image_size)
                img = img / 255.0
                if img.shape == (image_size[0], image_size[1], 3):
                    images.append(img)
                    labels.append(class_idx)
            except Exception as e:
                print(f"Error loading {img_path}: {str(e)}")

    return np.array(images), np.array(labels)

# -----------------------
# Load and Clean Datasets
# -----------------------
X_train, y_train = load_data_from_directory('aloe_dataset/train')
X_val, y_val = load_data_from_directory('aloe_dataset/val')
X_test, y_test = load_data_from_directory('aloe_dataset/test')

def remove_duplicates(primary_set, secondary_set):
    hashes = [hash(x.tobytes()) for x in primary_set]
    indices_to_keep = [i for i, x in enumerate(secondary_set) if hash(x.tobytes()) not in hashes]
    return secondary_set[indices_to_keep], indices_to_keep

X_val, keep_val = remove_duplicates(X_train, X_val)
y_val = y_val[keep_val]

X_test, keep_test = remove_duplicates(X_train, X_test)
y_test = y_test[keep_test]

X_test, keep_test2 = remove_duplicates(X_val, X_test)
y_test = y_test[keep_test2]

print(f"Cleaned Val: {X_val.shape}, Test: {X_test.shape}")

# -----------------------
# Without SMOTE (No Over-sampling)
# -----------------------
# Directly use the original training data without SMOTE
y_train_enc = to_categorical(y_train, num_classes=len(np.unique(y_train)))

# Shuffle the training data
X_train, y_train_enc = shuffle(X_train, y_train_enc, random_state=42)

# Encode validation and test
y_val_enc = to_categorical(y_val, num_classes=y_train_enc.shape[1])
y_test_enc = to_categorical(y_test, num_classes=y_train_enc.shape[1])

# -----------------------
# Image Augmentation
# -----------------------
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator()  # No augmentation for validation

train_generator = train_datagen.flow(
    X_train, y_train_enc,
    batch_size=32,
    shuffle=True,
    seed=42
)

val_generator = val_datagen.flow(
    X_val, y_val_enc,
    batch_size=32,
    shuffle=False
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 29
#      24     return np.array(images), np.array(labels)
#      26 # -----------------------
#      27 # Load and Clean Datasets
#      28 # -----------------------
# ---> 29 X_train, y_train = load_data_from_directory('aloe_dataset/train')
#      30 X_val, y_val = load_data_from_directory('aloe_dataset/val')
#      31 X_test, y_test = load_data_from_directory('aloe_dataset/test')
#
# Cell In[2], line 4, in load_data_from_directory(base_dir, image_size)
#       2 images = []
#       3 labels = []
# ----> 4 class_names = sorted(os.listdir(base_dir))
#       6 for class_idx, class_label in enumerate(class_names):
#       7     class_path = os.path.join(base_dir, class_label)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'aloe_dataset/train'

# %%
# === 2. CNN Model from Scratch ===
model = Sequential([
    Input(shape=(128, 128, 3)),

    Conv2D(32, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.0001),  # Lower learning rate helps stabilize training
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_72 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_68 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_73 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Check for duplicates between sets
def check_overlap(set1, set2):
    set1_hashes = [hash(x.tobytes()) for x in set1]
    set2_hashes = [hash(x.tobytes()) for x in set2]
    return len(set(set1_hashes) & set(set2_hashes))

print("Train-Val overlap:", check_overlap(X_train, X_val))
print("Train-Test overlap:", check_overlap(X_train, X_test))

# Check class distribution
print("Train counts:", np.unique(y_train, return_counts=True))
print("Val counts:", np.unique(y_val, return_counts=True))
# Out:
# Train-Val overlap: 5
# Train-Test overlap: 2
# Train counts: (array([0, 1, 2]), array([441, 586, 608], dtype=int64))
# Val counts: (array([0, 1, 2]), array([ 94, 125, 130], dtype=int64))

# %%
# Remove duplicate images between sets
def remove_duplicates(primary_set, secondary_set):
    hashes = [hash(x.tobytes()) for x in primary_set]
    indices_to_keep = [i for i,x in enumerate(secondary_set) 
                      if hash(x.tobytes()) not in hashes]
    return secondary_set[indices_to_keep]

X_val = remove_duplicates(X_train, X_val)
X_test = remove_duplicates(X_train, X_test)
y_val = y_val[:len(X_val)]
y_test = y_test[:len(X_test)]
X_test = remove_duplicates(X_val, X_test)
y_test = y_test[:len(X_test)]

# Verify new sizes
print(f"Cleaned Val: {X_val.shape}, Test: {X_test.shape}")

# Class balancing using SMOTE
from imblearn.over_sampling import SMOTE
smote = SMOTE()
X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
X_balanced, y_balanced = smote.fit_resample(X_train_reshaped, y_train)
X_balanced = X_balanced.reshape(-1, 128, 128, 3)

# Update one-hot encoding
y_train_enc = to_categorical(y_balanced)
# Out:
# Cleaned Val: (344, 128, 128, 3), Test: (349, 128, 128, 3)

# %%
# Verify your data splits don't overlap
print(f"Unique train samples: {len(set([tuple(x.flatten()) for x in X_train]))}")
print(f"Unique val samples: {len(set([tuple(x.flatten()) for x in X_val]))}")
# Out:
# Unique train samples: 1626
# Unique val samples: 348

# %%
# -----------------------
# Compile & Train Model
# -----------------------
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=5,
        verbose=1,
        restore_best_weights=True,
        mode='max',
        min_delta=0.001
    ),
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        verbose=1,
        min_lr=1e-6,
        mode='max'
    ),
    ModelCheckpoint(
        'best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        mode='max'
    )
]

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    callbacks=callbacks,
    verbose=1
)
# Out:
# c:\Users\David Ty\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8343 - loss: 0.5534
# Epoch 1: val_accuracy improved from -inf to 0.54360, saving model to best_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.8357 - loss: 0.5488 - val_accuracy: 0.5436 - val_loss: 3.1295 - learning_rate: 1.0000e-04
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9813 - loss: 0.0507
# Epoch 2: val_accuracy improved from 0.54360 to 0.56395, saving model to best_model.keras
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test_enc, verbose=1)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 246ms/step - accuracy: 0.9976 - loss: 0.0033
# Test Accuracy: 0.9943

# %%
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('Accuracy over Epochs')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Get model predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Convert true labels to encoded format
y_true = le.transform(y_test_enc)  # Not one-hot, just class indices

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Display confusion matrix with class names
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Test Data")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 import numpy as np
#       5 # Get model predictions
# ----> 6 y_pred_probs = model.predict(X_test)
#       7 y_pred = np.argmax(y_pred_probs, axis=1)
#       9 # Convert true labels to encoded format
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(history.history['accuracy']) + 1)

# Accuracy plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, history.history['accuracy'], label='Train Accuracy')
plt.plot(epochs, history.history['val_accuracy'], label='Val Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs, history.history['loss'], label='Train Loss')
plt.plot(epochs, history.history['val_loss'], label='Val Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.show()
